# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_csv('bbl_data.csv')

# Split the data into input (x) and output (y) variables
x = df[['x[1]', 'x[2]']].values
y = df['Y'].values

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a 2-layer neural network using the Sequential model
model = Sequential()
model.add(Dense(10, input_dim=2, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a mean squared error loss function and an Adam optimizer
model.compile(loss='mean_squared_error', optimizer='sgd')

# Train the model on the training data, and calculate the loss and R^2 on the testing data in each epoch
for epoch in range(100):
    model.fit(x_train, y_train, epochs=1, batch_size=32, verbose=0)
    y_pred = model.predict(x_test)
    loss = model.evaluate(x_test, y_test, verbose=0)
    r2 = r2_score(y_test, y_pred)
    print(f'Epoch {epoch+1}, Loss: {loss}, R^2: {r2}')
# Out:
# Epoch 1, Loss: 0.13775400817394257, R^2: 0.9485168589048472
# Epoch 2, Loss: 0.13197526335716248, R^2: 0.9506765486294917
# Epoch 3, Loss: 0.1295865923166275, R^2: 0.9515692914031153
# Epoch 4, Loss: 0.12279766798019409, R^2: 0.9541065294808299
# Epoch 5, Loss: 0.12127583473920822, R^2: 0.9546752799455557
# Epoch 6, Loss: 0.11712830513715744, R^2: 0.9562253510378265
# Epoch 7, Loss: 0.11073558032512665, R^2: 0.9586145223967186
# Epoch 8, Loss: 0.10812991112470627, R^2: 0.9595883367952598
# Epoch 9, Loss: 0.10094908624887466, R^2: 0.9622720495844417
# Epoch 10, Loss: 0.096469946205616, R^2: 0.9639460508346941
# Epoch 11, Loss: 0.09337242692708969, R^2: 0.9651036917537229
# Epoch 12, Loss: 0.08663371950387955, R^2: 0.9676221656522959
# Epoch 13, Loss: 0.07967393845319748, R^2: 0.970223258730429
# Epoch 14, Loss: 0.0758046954870224, R^2: 0.9716693183296915
# Epoch 15, Loss: 0.06877958029508591, R^2: 0.9742948379329404
# Epoch 16, Loss: 0.06757410615682602, R^2: 0.9747453649171087
# ...
